# %%
# !pip install git+https://github.com/DLR-RM/stable-baselines3@feat/gymnasium-support
# !pip install git+https://github.com/Stable-Baselines-Team/stable-baselines3-contrib@feat/gymnasium-support
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/DLR-RM/stable-baselines3@feat/gymnasium-support
#   Cloning https://github.com/DLR-RM/stable-baselines3 (to revision feat/gymnasium-support) to /tmp/pip-req-build-5_cabacx
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/stable-baselines3 /tmp/pip-req-build-5_cabacx
#   WARNING: Did not find branch or tag 'feat/gymnasium-support', assuming revision or ref.
#   Running command git checkout -q feat/gymnasium-support
#   error: pathspec 'feat/gymnasium-support' did not match any file(s) known to git
#   error: subprocess-exited-with-error
#
#   × git checkout -q feat/gymnasium-support did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × git checkout -q feat/gymnasium-support did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/Stable-Baselines-Team/stable-baselines3-contrib@feat/gymnasium-support
#   Cloning https://github.com/Stable-Baselines-Team/stable-baselines3-contrib (to revision feat/gymnasium-support) to /tmp/pip-req-build-9xn_emsd
#   Running command git clone --filter=blob:none --quiet https://github.com/Stable-Baselines-Team/stable-baselines3-contrib /tmp/pip-req-build-9xn_emsd
#   Running command git checkout -b feat/gymnasium-support --track origin/feat/gymnasium-support
#   Switched to a new branch 'feat/gymnasium-support'
#   Branch 'feat/gymnasium-support' set up to track remote branch 'feat/gymnasium-support' from 'origin'.
#   Resolved https://github.com/Stable-Baselines-Team/stable-baselines3-contrib to commit d93ca7f1a734436cee59d642fa7d3eb8b4ed0253
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: stable-baselines3>=2.0.0a4 in /usr/local/lib/python3.10/dist-packages (from sb3-contrib==2.0.0a4) (2.0.0a5)
# Requirement already satisfied: gymnasium==0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (0.28.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (1.22.4)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (2.0.0+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (3.7.1)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (16.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11->stable-baselines3>=2.0.0a4->sb3-contrib==2.0.0a4) (1.3.0)

# %%
# !pip install gym-anytrading
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gym-anytrading in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: gym>=0.12.5 in /usr/local/lib/python3.10/dist-packages (from gym-anytrading) (0.25.2)
# Requirement already satisfied: numpy>=1.16.4 in /usr/local/lib/python3.10/dist-packages (from gym-anytrading) (1.22.4)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from gym-anytrading) (1.5.3)
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from gym-anytrading) (3.7.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym>=0.12.5->gym-anytrading) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym>=0.12.5->gym-anytrading) (0.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->gym-anytrading) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->gym-anytrading) (1.16.0)

# %%
# !pip install shimmy>=0.2.1

# %%
# !pip install finta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: finta in /usr/local/lib/python3.10/dist-packages (1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from finta) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from finta) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->finta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->finta) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->finta) (1.16.0)

# %%
# !pip install quantstats
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: quantstats in /usr/local/lib/python3.10/dist-packages (0.0.59)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from quantstats) (1.22.4)
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (0.12.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (3.7.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (1.10.1)
# Requirement already satisfied: tabulate>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (0.8.10)
# Requirement already satisfied: yfinance>=0.1.70 in /usr/local/lib/python3.10/dist-packages (from quantstats) (0.2.18)
# Requirement already satisfied: python-dateutil>=2.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->quantstats) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.0->quantstats) (1.16.0)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (2.27.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (2.3.7)
# Requirement already satisfied: cryptography>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (40.0.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance>=0.1.70->quantstats) (2.4.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.3.2->yfinance>=0.1.70->quantstats) (1.15.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance>=0.1.70->quantstats) (0.5.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance>=0.1.70->quantstats) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance>=0.1.70->quantstats) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance>=0.1.70->quantstats) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance>=0.1.70->quantstats) (3.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance>=0.1.70->quantstats) (2.21)

# %%
# Gym stuff
import gym
import gym_anytrading
from gym_anytrading.envs import StocksEnv

# Stable baselines - rl stuff
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import A2C
from stable_baselines3.common.sb2_compat.rmsprop_tf_like import RMSpropTFLike

#Quant Finance
from finta import TA
import quantstats as qs

# Processing libraries
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(

# %%
from google.colab import drive
drive.mount('/content/drive/')

with open('/content/drive/MyDrive/Alpaca_Keys.txt', 'r') as f:
  keys = f.readlines()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# from a list of keys we take the first one - '/n'
api_key = keys[0][:-1]
secret_key = keys[1]

# %% [markdown]
# ## Alpaca

# %%
# !pip install alpaca-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: alpaca-py in /usr/local/lib/python3.10/dist-packages (0.8.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from alpaca-py) (1.0.5)
# Requirement already satisfied: pandas<2.0.0,>=1.3.5 in /usr/local/lib/python3.10/dist-packages (from alpaca-py) (1.5.3)
# Requirement already satisfied: pydantic<2.0.0,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from alpaca-py) (1.10.7)
# Requirement already satisfied: requests<3.0.0,>=2.27.1 in /usr/local/lib/python3.10/dist-packages (from alpaca-py) (2.27.1)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in /usr/local/lib/python3.10/dist-packages (from alpaca-py) (1.7.2)
# Requirement already satisfied: websockets<11.0,>=10.2 in /usr/local/lib/python3.10/dist-packages (from alpaca-py) (10.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.3.5->alpaca-py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.3.5->alpaca-py) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.3.5->alpaca-py) (1.22.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.0.0,>=1.9.0->alpaca-py) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.27.1->alpaca-py) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.27.1->alpaca-py) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.27.1->alpaca-py) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.27.1->alpaca-py) (3.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.3.5->alpaca-py) (1.16.0)

# %%
from alpaca.data.historical import StockHistoricalDataClient
from alpaca.data.requests import StockBarsRequest
from alpaca.data.timeframe import TimeFrame
from datetime import datetime


client = StockHistoricalDataClient(api_key,secret_key)

request_params = StockBarsRequest(
                        symbol_or_symbols=["AAPL"],
                        timeframe=TimeFrame.Minute,
                        start=datetime(2022, 5, 1)
                 )

bars = client.get_stock_bars(request_params)

# %%
data = bars.df
data = data.droplevel(0)
data.head()
# Out:
#                              open    high     low   close  volume  \
# timestamp
# 2022-05-02 06:03:00+00:00  158.87  158.87  158.87  158.87   155.0
# 2022-05-02 08:00:00+00:00  158.60  158.60  158.10  158.10  1628.0
# 2022-05-02 08:01:00+00:00  158.54  158.54  158.48  158.48  1050.0
# 2022-05-02 08:02:00+00:00  158.54  158.54  158.54  158.54   240.0
# 2022-05-02 08:03:00+00:00  158.63  158.64  158.53  158.53  2246.0
#
#                            trade_count        vwap
# timestamp
# 2022-05-02 06:03:00+00:00          1.0  158.870000
# 2022-05-02 08:00:00+00:00         63.0  158.501824
# 2022-05-02 08:01:00+00:00         76.0  158.460895
# 2022-05-02 08:02:00+00:00         21.0  158.587792
# 2022-05-02 08:03:00+00:00         75.0  158.575588

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 208570 entries, 2022-05-02 06:03:00+00:00 to 2023-05-12 18:11:00+00:00
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   open         208570 non-null  float64
#  1   high         208570 non-null  float64
#  2   low          208570 non-null  float64
#  3   close        208570 non-null  float64
#  4   volume       208570 non-null  float64
#  5   trade_count  208570 non-null  float64
#  6   vwap         208570 non-null  float64
# dtypes: float64(7)
# memory usage: 12.7 MB

# %%
data = data.rename(columns = {'open': 'Open', 'high': 'High', 'low': 'Low', 'close': 'Close', 'volume': 'Volume'})

# %% [markdown]
# ## Alpha Vantage

# %%
#Download 3 months of data (Alphavantage only provides 1 month per call)
month_1 = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY_EXTENDED&symbol=AAPL&interval=5min&slice=year1month1&apikey={key}&datatype=csv'
month_2 = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY_EXTENDED&symbol=AAPL&interval=5min&slice=year1month2&apikey={key}&datatype=csv'
month_3 = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY_EXTENDED&symbol=AAPL&interval=5min&slice=year1month3&apikey={key}&datatype=csv'
month_4 = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY_EXTENDED&symbol=AAPL&interval=5min&slice=year1month4&apikey={key}&datatype=csv'

#Grab the Data as CSV
csv_1 = pd.read_csv(month_1)
csv_2 = pd.read_csv(month_2)
csv_3 = pd.read_csv(month_3)
csv_4 = pd.read_csv(month_4)

#Put it into a DataFrame
data_1 = pd.DataFrame(csv_1)
data_2 = pd.DataFrame(csv_2)
data_3 = pd.DataFrame(csv_3)
data_4 = pd.DataFrame(csv_4)


#Append the three months into one Dataframe
data = data_1.append([data_2, data_3, data_4])

data.head(3)

# %%
data.info()

# %%
data = data.rename(columns = {'open': 'Open', 'high': 'High', 'low': 'Low', 'close': 'Close', 'volume': 'Volume'})

data['time'] = pd.to_datetime(data['time'])
data.set_index('time', inplace=True)
data.sort_values('time', ascending=True, inplace=True)

data.head()

# %% [markdown]
# ## Add Custom Indicators

# %%
data['return'] = np.log(data['Close'] / data['Close'].shift(1))

# %%
#Create columns for technical indicators & add them to the dataframe
data['RSI'] = TA.RSI(data,16)
data['SMA'] = TA.SMA(data, 20)
data['SMA_L'] = TA.SMA(data, 41)
data['OBV'] = TA.OBV(data)
#data['VWAP'] = TA.VWAP(data)
data['EMA'] = TA.EMA(data)
data['ATR'] = TA.ATR(data)
data.fillna(0, inplace=True)

# %%
#Add momentum, volatitlity, & distance to the data_frame
data['momentum'] = data['return'].rolling(5).mean().shift(1)
data['volatility'] = data['return'].rolling(20).std().shift(1)
data['distance'] = (data['Close'] - data['Close'].rolling(50).mean()).shift(1)

# %%
#Perform a simple linear regression direction prediction
lags = 5

cols = []
for lag in range(1, lags + 1):
  col = f'lag_{lag}'
  data[col] = data['Close'].shift(lag)
  cols.append(col)

data.dropna(inplace=True)

reg = np.linalg.lstsq(data[cols], data['Close'], rcond=None)[0]
data['Prediction'] = np.dot(data[cols], reg)

# %%
data.tail()
# Out:
#                                Open    High       Low     Close   Volume  \
# timestamp
# 2023-05-12 18:07:00+00:00  171.1100  171.27  171.0800  171.2518  78099.0
# 2023-05-12 18:08:00+00:00  171.2600  171.27  171.1600  171.2250  68661.0
# 2023-05-12 18:09:00+00:00  171.2150  171.25  171.2000  171.2275  41369.0
# 2023-05-12 18:10:00+00:00  171.2296  171.37  171.2296  171.3407  62886.0
# 2023-05-12 18:11:00+00:00  171.3500  171.40  171.2850  171.3000  67999.0
#
#                            trade_count        vwap    return        RSI  \
# timestamp
# 2023-05-12 18:07:00+00:00        844.0  171.162938  0.000858  40.775203
# 2023-05-12 18:08:00+00:00        855.0  171.216529 -0.000157  39.521614
# 2023-05-12 18:09:00+00:00        531.0  171.219199  0.000015  39.706059
# 2023-05-12 18:10:00+00:00        715.0  171.302643  0.000661  47.447081
# 2023-05-12 18:11:00+00:00        744.0  171.338276 -0.000238  45.220508
#
#                                   SMA  ...       ATR  momentum  volatility  \
# timestamp                              ...
# 2023-05-12 18:07:00+00:00  171.348150  ...  0.104014 -0.000064    0.000292
# 2023-05-12 18:08:00+00:00  171.328075  ...  0.106236  0.000037    0.000357
# 2023-05-12 18:09:00+00:00  171.307200  ...  0.104093  0.000018    0.000356
# 2023-05-12 18:10:00+00:00  171.296235  ...  0.106400 -0.000026    0.000354
# 2023-05-12 18:11:00+00:00  171.283735  ...  0.110321  0.000147    0.000383
#
#                            distance     lag_1     lag_2     lag_3     lag_4  \
# timestamp
# 2023-05-12 18:07:00+00:00 -0.478664  171.1050  171.2150  171.2500  171.2100
# 2023-05-12 18:08:00+00:00 -0.326400  171.2518  171.1050  171.2150  171.2500
# 2023-05-12 18:09:00+00:00 -0.346500  171.2250  171.2518  171.1050  171.2150
# 2023-05-12 18:10:00+00:00 -0.337150  171.2275  171.2250  171.2518  171.1050
# 2023-05-12 18:11:00+00:00 -0.219464  171.3407  171.2275  171.2250  171.2518
#
#                              lag_5  Prediction
# timestamp
# 2023-05-12 18:07:00+00:00  171.220  171.112899
# 2023-05-12 18:08:00+00:00  171.210  171.244059
# 2023-05-12 18:09:00+00:00  171.250  171.224929
# 2023-05-12 18:10:00+00:00  171.215  171.228091
# 2023-05-12 18:11:00+00:00  171.105  171.331901
#
# [5 rows x 23 columns]

# %%
#Create a function to properly format data frame to be passed through environment
def signals(env):
    start = env.frame_bound[0] - env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:,'Close'].to_numpy()[start:end]
    signal_features = env.df.loc[:, ['Open','High','Low','Volume','return','trade_count','momentum','volatility','distance','RSI','OBV','SMA','SMA_L','vwap','EMA','ATR', 'Prediction']].to_numpy()[start:end]
    return prices, signal_features

# %%
#Replace default data process with custom function from above
class MyCustomEnv(StocksEnv):
    _process_data = signals

#Initialize an environment setting the window size and train data
window_size = 65
start_index = window_size
end_train_index = round(len(data)*0.80)
end_val_index = len(data)

env2 = MyCustomEnv(df=data, window_size=window_size, frame_bound=(start_index, end_train_index))

# %%
#Create a Dummy Vector of our environment
env_maker = lambda: env2
env = DummyVecEnv([env_maker])
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %% [markdown]
# ## Train Test

# %%
#initialize our model and train
policy_kwargs = dict(optimizer_class=RMSpropTFLike, optimizer_kwargs=dict(eps=1e-5))
actor_critic = A2C('MlpPolicy', env, policy_kwargs=policy_kwargs, verbose=1)
actor_critic.learn(total_timesteps=200000)
# Out:
# Streaming output truncated to the last 5000 lines.
# |    value_loss         | 0.000363 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 4400     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.515   |
# |    explained_variance | -0.0541  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.07    |
# |    value_loss         | 0.0315   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 4500     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -0.3     |
# |    explained_variance | -60.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 0.000264 |
# |    value_loss         | 2.32e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 381       |
# |    iterations         | 4600      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -0.201    |
# |    explained_variance | -523      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | -0.000934 |
# |    value_loss         | 0.000565  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 381       |
# |    iterations         | 4700      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -0.256    |
# |    explained_variance | -2.4e+05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | -0.000366 |
# |    value_loss         | 0.00121   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 4800     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.146   |
# |    explained_variance | -164     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.000229 |
# |    value_loss         | 0.000102 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 4900     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -0.124   |
# |    explained_variance | -43.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 4.74e-05 |
# |    value_loss         | 0.000132 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 378       |
# |    iterations         | 5000      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -0.119    |
# |    explained_variance | -1.01e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | 0.000404  |
# |    value_loss         | 0.000385  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 5100     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -0.114   |
# |    explained_variance | -192     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.000133 |
# |    value_loss         | 0.000112 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 5200     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.154   |
# |    explained_variance | -267     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.000523 |
# |    value_loss         | 0.000402 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 5300     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -0.144   |
# |    explained_variance | -0.0235  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.319   |
# |    value_loss         | 0.0946   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 5400     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -0.148   |
# |    explained_variance | -220     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 0.000228 |
# |    value_loss         | 0.000802 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 5500     |
# |    time_elapsed       | 73       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.104   |
# |    explained_variance | -53.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.000116 |
# |    value_loss         | 5e-05    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 375       |
# |    iterations         | 5600      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -0.197    |
# |    explained_variance | -1.39e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -0.000951 |
# |    value_loss         | 0.000453  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 5700     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -0.347   |
# |    explained_variance | -101     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.0107  |
# |    value_loss         | 0.00766  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 5800     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.123   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 2.73e-05 |
# |    value_loss         | 1.24e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 5900     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -0.214   |
# |    explained_variance | -30.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.00141  |
# |    value_loss         | 0.000623 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 373       |
# |    iterations         | 6000      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -0.147    |
# |    explained_variance | -1.25e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | 0.000174  |
# |    value_loss         | 0.000144  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 371      |
# |    iterations         | 6100     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.0965  |
# |    explained_variance | 0.289    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.0119  |
# |    value_loss         | 0.000585 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 371       |
# |    iterations         | 6200      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -0.157    |
# |    explained_variance | -458      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | -0.000626 |
# |    value_loss         | 0.000703  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 371      |
# |    iterations         | 6300     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -0.112   |
# |    explained_variance | -0.21    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.143    |
# |    value_loss         | 0.00724  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 371       |
# |    iterations         | 6400      |
# |    time_elapsed       | 86        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -0.178    |
# |    explained_variance | -546      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -0.000238 |
# |    value_loss         | 0.00033   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 371      |
# |    iterations         | 6500     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.0614  |
# |    explained_variance | -0.193   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | 4.03e-05 |
# |    value_loss         | 1.5e-05  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 372       |
# |    iterations         | 6600      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -0.093    |
# |    explained_variance | -2.47e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | 2.13e-05  |
# |    value_loss         | 6.73e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 372       |
# |    iterations         | 6700      |
# |    time_elapsed       | 90        |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -0.121    |
# |    explained_variance | -1.44e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | -0.00139  |
# |    value_loss         | 0.00207   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 372       |
# |    iterations         | 6800      |
# |    time_elapsed       | 91        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -0.0435   |
# |    explained_variance | -193      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | -1.27e-05 |
# |    value_loss         | 5.01e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 371       |
# |    iterations         | 6900      |
# |    time_elapsed       | 92        |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -0.0571   |
# |    explained_variance | -3.57e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | 4.43e-05  |
# |    value_loss         | 6.22e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 7000     |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -0.158   |
# |    explained_variance | -106     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 0.000139 |
# |    value_loss         | 4.13e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 368       |
# |    iterations         | 7100      |
# |    time_elapsed       | 96        |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -0.107    |
# |    explained_variance | -11.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -0.000249 |
# |    value_loss         | 0.000119  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 368      |
# |    iterations         | 7200     |
# |    time_elapsed       | 97       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.283   |
# |    explained_variance | -0.32    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | -0.123   |
# |    value_loss         | 0.0257   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 368      |
# |    iterations         | 7300     |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -0.347   |
# |    explained_variance | -801     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | 0.00106  |
# |    value_loss         | 0.000323 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 369       |
# |    iterations         | 7400      |
# |    time_elapsed       | 100       |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -0.158    |
# |    explained_variance | -117      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -9.58e-05 |
# |    value_loss         | 8.92e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 368      |
# |    iterations         | 7500     |
# |    time_elapsed       | 101      |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.434   |
# |    explained_variance | 0.071    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | -0.0728  |
# |    value_loss         | 0.0138   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 7600     |
# |    time_elapsed       | 102      |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.475   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | -0.0113  |
# |    value_loss         | 0.000455 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 7700     |
# |    time_elapsed       | 104      |
# |    total_timesteps    | 38500    |
# | train/                |          |
# |    entropy_loss       | -0.658   |
# |    explained_variance | -2.98    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7699     |
# |    policy_loss        | -0.0177  |
# |    value_loss         | 0.00105  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 7800     |
# |    time_elapsed       | 105      |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -0.684   |
# |    explained_variance | -0.391   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | -0.0813  |
# |    value_loss         | 0.0191   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 368      |
# |    iterations         | 7900     |
# |    time_elapsed       | 107      |
# |    total_timesteps    | 39500    |
# | train/                |          |
# |    entropy_loss       | -0.678   |
# |    explained_variance | 0.0931   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7899     |
# |    policy_loss        | 0.00291  |
# |    value_loss         | 0.00112  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 8000     |
# |    time_elapsed       | 109      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -0.653   |
# |    explained_variance | -0.512   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7999     |
# |    policy_loss        | 0.0286   |
# |    value_loss         | 0.00653  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 366       |
# |    iterations         | 8100      |
# |    time_elapsed       | 110       |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -0.661    |
# |    explained_variance | -1.07e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8099      |
# |    policy_loss        | -0.0218   |
# |    value_loss         | 0.00112   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 8200     |
# |    time_elapsed       | 111      |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -0.6     |
# |    explained_variance | -0.0456  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | 0.0181   |
# |    value_loss         | 0.0087   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 366       |
# |    iterations         | 8300      |
# |    time_elapsed       | 113       |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -0.571    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8299      |
# |    policy_loss        | 0.0157    |
# |    value_loss         | 0.000732  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 8400     |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.642   |
# |    explained_variance | -563     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8399     |
# |    policy_loss        | -0.0123  |
# |    value_loss         | 0.00252  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 8500     |
# |    time_elapsed       | 115      |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -0.624   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | 0.00813  |
# |    value_loss         | 0.000378 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 8600     |
# |    time_elapsed       | 117      |
# |    total_timesteps    | 43000    |
# | train/                |          |
# |    entropy_loss       | -0.482   |
# |    explained_variance | -0.29    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8599     |
# |    policy_loss        | 0.0448   |
# |    value_loss         | 0.00279  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 367       |
# |    iterations         | 8700      |
# |    time_elapsed       | 118       |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -0.337    |
# |    explained_variance | -76       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | -0.000729 |
# |    value_loss         | 8.85e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 8800     |
# |    time_elapsed       | 119      |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -0.292   |
# |    explained_variance | -63.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8799     |
# |    policy_loss        | 0.000667 |
# |    value_loss         | 9.89e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 366       |
# |    iterations         | 8900      |
# |    time_elapsed       | 121       |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -0.481    |
# |    explained_variance | -1.94e+05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | -0.00189  |
# |    value_loss         | 0.000189  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 364       |
# |    iterations         | 9000      |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -0.387    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8999      |
# |    policy_loss        | -0.000157 |
# |    value_loss         | 1.54e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 364       |
# |    iterations         | 9100      |
# |    time_elapsed       | 124       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -0.352    |
# |    explained_variance | -697      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | -0.000963 |
# |    value_loss         | 7.91e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 364       |
# |    iterations         | 9200      |
# |    time_elapsed       | 126       |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -0.285    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9199      |
# |    policy_loss        | -0.000109 |
# |    value_loss         | 1.96e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 365      |
# |    iterations         | 9300     |
# |    time_elapsed       | 127      |
# |    total_timesteps    | 46500    |
# | train/                |          |
# |    entropy_loss       | -0.198   |
# |    explained_variance | -133     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9299     |
# |    policy_loss        | 0.000218 |
# |    value_loss         | 2.94e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 365      |
# |    iterations         | 9400     |
# |    time_elapsed       | 128      |
# |    total_timesteps    | 47000    |
# | train/                |          |
# |    entropy_loss       | -0.354   |
# |    explained_variance | -146     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9399     |
# |    policy_loss        | -0.00167 |
# |    value_loss         | 0.000365 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 365      |
# |    iterations         | 9500     |
# |    time_elapsed       | 129      |
# |    total_timesteps    | 47500    |
# | train/                |          |
# |    entropy_loss       | -0.271   |
# |    explained_variance | -0.119   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9499     |
# |    policy_loss        | 0.0335   |
# |    value_loss         | 0.00285  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 365      |
# |    iterations         | 9600     |
# |    time_elapsed       | 131      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -0.214   |
# |    explained_variance | -30      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9599     |
# |    policy_loss        | 0.000145 |
# |    value_loss         | 9.28e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 365      |
# |    iterations         | 9700     |
# |    time_elapsed       | 132      |
# |    total_timesteps    | 48500    |
# | train/                |          |
# |    entropy_loss       | -0.264   |
# |    explained_variance | -176     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9699     |
# |    policy_loss        | 0.00147  |
# |    value_loss         | 0.000396 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 365       |
# |    iterations         | 9800      |
# |    time_elapsed       | 133       |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -0.176    |
# |    explained_variance | -167      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9799      |
# |    policy_loss        | -0.000202 |
# |    value_loss         | 5.38e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 364      |
# |    iterations         | 9900     |
# |    time_elapsed       | 135      |
# |    total_timesteps    | 49500    |
# | train/                |          |
# |    entropy_loss       | -0.399   |
# |    explained_variance | -21.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9899     |
# |    policy_loss        | -0.00222 |
# |    value_loss         | 0.000256 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 10000    |
# |    time_elapsed       | 137      |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -0.132   |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9999     |
# |    policy_loss        | 5.97e-05 |
# |    value_loss         | 4.9e-06  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 10100    |
# |    time_elapsed       | 138      |
# |    total_timesteps    | 50500    |
# | train/                |          |
# |    entropy_loss       | -0.222   |
# |    explained_variance | -265     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10099    |
# |    policy_loss        | 0.000506 |
# |    value_loss         | 0.000353 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 363       |
# |    iterations         | 10200     |
# |    time_elapsed       | 140       |
# |    total_timesteps    | 51000     |
# | train/                |           |
# |    entropy_loss       | -0.286    |
# |    explained_variance | -302      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 10199     |
# |    policy_loss        | -0.000365 |
# |    value_loss         | 9.25e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 10300    |
# |    time_elapsed       | 141      |
# |    total_timesteps    | 51500    |
# | train/                |          |
# |    entropy_loss       | -0.185   |
# |    explained_variance | -11.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10299    |
# |    policy_loss        | 0.000553 |
# |    value_loss         | 0.000193 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 10400    |
# |    time_elapsed       | 142      |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -0.342   |
# |    explained_variance | -0.0411  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10399    |
# |    policy_loss        | 0.109    |
# |    value_loss         | 0.0281   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 364      |
# |    iterations         | 10500    |
# |    time_elapsed       | 144      |
# |    total_timesteps    | 52500    |
# | train/                |          |
# |    entropy_loss       | -0.0868  |
# |    explained_variance | -13.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10499    |
# |    policy_loss        | 0.000202 |
# |    value_loss         | 0.000275 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 364       |
# |    iterations         | 10600     |
# |    time_elapsed       | 145       |
# |    total_timesteps    | 53000     |
# | train/                |           |
# |    entropy_loss       | -0.128    |
# |    explained_variance | -8.08e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 10599     |
# |    policy_loss        | 0.000292  |
# |    value_loss         | 0.000144  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 364      |
# |    iterations         | 10700    |
# |    time_elapsed       | 146      |
# |    total_timesteps    | 53500    |
# | train/                |          |
# |    entropy_loss       | -0.248   |
# |    explained_variance | -53.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10699    |
# |    policy_loss        | 0.00471  |
# |    value_loss         | 0.000124 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 364      |
# |    iterations         | 10800    |
# |    time_elapsed       | 148      |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -0.345   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10799    |
# |    policy_loss        | 0.041    |
# |    value_loss         | 0.00556  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 10900    |
# |    time_elapsed       | 150      |
# |    total_timesteps    | 54500    |
# | train/                |          |
# |    entropy_loss       | -0.497   |
# |    explained_variance | -81.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10899    |
# |    policy_loss        | 0.00516  |
# |    value_loss         | 0.000615 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 362       |
# |    iterations         | 11000     |
# |    time_elapsed       | 151       |
# |    total_timesteps    | 55000     |
# | train/                |           |
# |    entropy_loss       | -0.311    |
# |    explained_variance | -2.87e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 10999     |
# |    policy_loss        | 0.000379  |
# |    value_loss         | 0.000296  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 11100    |
# |    time_elapsed       | 153      |
# |    total_timesteps    | 55500    |
# | train/                |          |
# |    entropy_loss       | -0.229   |
# |    explained_variance | -6.41    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11099    |
# |    policy_loss        | 0.00944  |
# |    value_loss         | 0.000156 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 11200    |
# |    time_elapsed       | 154      |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -0.538   |
# |    explained_variance | 0.183    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11199    |
# |    policy_loss        | 0.0247   |
# |    value_loss         | 0.00263  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 11300    |
# |    time_elapsed       | 155      |
# |    total_timesteps    | 56500    |
# | train/                |          |
# |    entropy_loss       | -0.607   |
# |    explained_variance | -8.28    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11299    |
# |    policy_loss        | -0.0249  |
# |    value_loss         | 0.00142  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 11400    |
# |    time_elapsed       | 157      |
# |    total_timesteps    | 57000    |
# | train/                |          |
# |    entropy_loss       | -0.676   |
# |    explained_variance | -9.7     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11399    |
# |    policy_loss        | 0.115    |
# |    value_loss         | 0.0245   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 11500    |
# |    time_elapsed       | 158      |
# |    total_timesteps    | 57500    |
# | train/                |          |
# |    entropy_loss       | -0.679   |
# |    explained_variance | -59.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11499    |
# |    policy_loss        | 0.0447   |
# |    value_loss         | 0.00418  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 11600    |
# |    time_elapsed       | 159      |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -0.634   |
# |    explained_variance | -0.709   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11599    |
# |    policy_loss        | 0.0517   |
# |    value_loss         | 0.00402  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 363       |
# |    iterations         | 11700     |
# |    time_elapsed       | 161       |
# |    total_timesteps    | 58500     |
# | train/                |           |
# |    entropy_loss       | -0.615    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 11699     |
# |    policy_loss        | 0.0497    |
# |    value_loss         | 0.00691   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 11800    |
# |    time_elapsed       | 162      |
# |    total_timesteps    | 59000    |
# | train/                |          |
# |    entropy_loss       | -0.676   |
# |    explained_variance | -276     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11799    |
# |    policy_loss        | 0.0115   |
# |    value_loss         | 0.000563 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 11900    |
# |    time_elapsed       | 164      |
# |    total_timesteps    | 59500    |
# | train/                |          |
# |    entropy_loss       | -0.609   |
# |    explained_variance | -17      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11899    |
# |    policy_loss        | 0.0274   |
# |    value_loss         | 0.00115  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 12000    |
# |    time_elapsed       | 166      |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -0.677   |
# |    explained_variance | -0.0883  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 11999    |
# |    policy_loss        | -0.00065 |
# |    value_loss         | 0.00073  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 12100    |
# |    time_elapsed       | 167      |
# |    total_timesteps    | 60500    |
# | train/                |          |
# |    entropy_loss       | -0.668   |
# |    explained_variance | -8.01    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12099    |
# |    policy_loss        | -0.0186  |
# |    value_loss         | 0.000974 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 12200    |
# |    time_elapsed       | 168      |
# |    total_timesteps    | 61000    |
# | train/                |          |
# |    entropy_loss       | -0.659   |
# |    explained_variance | -0.59    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12199    |
# |    policy_loss        | -0.0356  |
# |    value_loss         | 0.00239  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 12300    |
# |    time_elapsed       | 169      |
# |    total_timesteps    | 61500    |
# | train/                |          |
# |    entropy_loss       | -0.68    |
# |    explained_variance | -0.21    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12299    |
# |    policy_loss        | -0.0116  |
# |    value_loss         | 0.00368  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 12400    |
# |    time_elapsed       | 171      |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -0.542   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12399    |
# |    policy_loss        | -0.0101  |
# |    value_loss         | 0.000223 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 12500    |
# |    time_elapsed       | 172      |
# |    total_timesteps    | 62500    |
# | train/                |          |
# |    entropy_loss       | -0.481   |
# |    explained_variance | -110     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12499    |
# |    policy_loss        | 0.0017   |
# |    value_loss         | 0.00014  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 12600    |
# |    time_elapsed       | 173      |
# |    total_timesteps    | 63000    |
# | train/                |          |
# |    entropy_loss       | -0.415   |
# |    explained_variance | -130     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12599    |
# |    policy_loss        | -0.00185 |
# |    value_loss         | 0.000728 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 362       |
# |    iterations         | 12700     |
# |    time_elapsed       | 175       |
# |    total_timesteps    | 63500     |
# | train/                |           |
# |    entropy_loss       | -0.149    |
# |    explained_variance | -17       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 12699     |
# |    policy_loss        | -0.000148 |
# |    value_loss         | 7.91e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 12800    |
# |    time_elapsed       | 177      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -0.214   |
# |    explained_variance | -1.4e+04 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12799    |
# |    policy_loss        | 0.000115 |
# |    value_loss         | 0.000335 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 360      |
# |    iterations         | 12900    |
# |    time_elapsed       | 178      |
# |    total_timesteps    | 64500    |
# | train/                |          |
# |    entropy_loss       | -0.0668  |
# |    explained_variance | -53.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 12899    |
# |    policy_loss        | 4.01e-05 |
# |    value_loss         | 0.000109 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 360       |
# |    iterations         | 13000     |
# |    time_elapsed       | 180       |
# |    total_timesteps    | 65000     |
# | train/                |           |
# |    entropy_loss       | -0.063    |
# |    explained_variance | -9.77e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 12999     |
# |    policy_loss        | -3.46e-05 |
# |    value_loss         | 1.1e-05   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 360      |
# |    iterations         | 13100    |
# |    time_elapsed       | 181      |
# |    total_timesteps    | 65500    |
# | train/                |          |
# |    entropy_loss       | -0.0757  |
# |    explained_variance | -82      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 13099    |
# |    policy_loss        | 4.92e-05 |
# |    value_loss         | 8.81e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 360      |
# |    iterations         | 13200    |
# |    time_elapsed       | 182      |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -0.13    |
# |    explained_variance | -50.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 13199    |
# |    policy_loss        | -5.1e-05 |
# |    value_loss         | 2.31e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 360      |
# |    iterations         | 13300    |
# |    time_elapsed       | 184      |
# |    total_timesteps    | 66500    |
# | train/                |          |
# |    entropy_loss       | -0.21    |
# |    explained_variance | -40.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 13299    |
# |    policy_loss        | 0.00154  |
# |    value_loss         | 0.000851 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 361       |
# |    iterations         | 13400     |
# |    time_elapsed       | 185       |
# |    total_timesteps    | 67000     |
# | train/                |           |
# |    entropy_loss       | -0.0839   |
# |    explained_variance | -8.74     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 13399     |
# |    policy_loss        | -0.000119 |
# |    value_loss         | 0.000113  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 361       |
# |    iterations         | 13500     |
# |    time_elapsed       | 186       |
# |    total_timesteps    | 67500     |
# | train/                |           |
# |    entropy_loss       | -0.0316   |
# |    explained_variance | -1.19e-07 |
# ...
# |    n_updates          | 36999    |
# |    policy_loss        | 9.02e-09 |
# |    value_loss         | 6.29e-09 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 361       |
# |    iterations         | 37100     |
# |    time_elapsed       | 513       |
# |    total_timesteps    | 185500    |
# | train/                |           |
# |    entropy_loss       | -0.00359  |
# |    explained_variance | -3.42     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 37099     |
# |    policy_loss        | -1.55e-06 |
# |    value_loss         | 4.33e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 361       |
# |    iterations         | 37200     |
# |    time_elapsed       | 514       |
# |    total_timesteps    | 186000    |
# | train/                |           |
# |    entropy_loss       | -0.00173  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 37199     |
# |    policy_loss        | -1.96e-08 |
# |    value_loss         | 1.45e-08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 361       |
# |    iterations         | 37300     |
# |    time_elapsed       | 516       |
# |    total_timesteps    | 186500    |
# | train/                |           |
# |    entropy_loss       | -0.0036   |
# |    explained_variance | -6.33     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 37299     |
# |    policy_loss        | -5.74e-07 |
# |    value_loss         | 5.95e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 361       |
# |    iterations         | 37400     |
# |    time_elapsed       | 517       |
# |    total_timesteps    | 187000    |
# | train/                |           |
# |    entropy_loss       | -0.00454  |
# |    explained_variance | -128      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 37399     |
# |    policy_loss        | -2.72e-06 |
# |    value_loss         | 4.25e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 361       |
# |    iterations         | 37500     |
# |    time_elapsed       | 518       |
# |    total_timesteps    | 187500    |
# | train/                |           |
# |    entropy_loss       | -0.00181  |
# |    explained_variance | -38.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 37499     |
# |    policy_loss        | -7.92e-07 |
# |    value_loss         | 2.06e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 37600    |
# |    time_elapsed       | 519      |
# |    total_timesteps    | 188000   |
# | train/                |          |
# |    entropy_loss       | -0.00679 |
# |    explained_variance | -100     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 37599    |
# |    policy_loss        | -6.9e-06 |
# |    value_loss         | 6.28e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 362       |
# |    iterations         | 37700     |
# |    time_elapsed       | 520       |
# |    total_timesteps    | 188500    |
# | train/                |           |
# |    entropy_loss       | -0.00178  |
# |    explained_variance | -1.18e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 37699     |
# |    policy_loss        | 5.7e-08   |
# |    value_loss         | 1.43e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 362       |
# |    iterations         | 37800     |
# |    time_elapsed       | 521       |
# |    total_timesteps    | 189000    |
# | train/                |           |
# |    entropy_loss       | -0.0023   |
# |    explained_variance | -31.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 37799     |
# |    policy_loss        | -1.87e-07 |
# |    value_loss         | 9.68e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 37900    |
# |    time_elapsed       | 523      |
# |    total_timesteps    | 189500   |
# | train/                |          |
# |    entropy_loss       | -0.0133  |
# |    explained_variance | -323     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 37899    |
# |    policy_loss        | 5.16e-06 |
# |    value_loss         | 3.78e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 38000    |
# |    time_elapsed       | 524      |
# |    total_timesteps    | 190000   |
# | train/                |          |
# |    entropy_loss       | -0.00273 |
# |    explained_variance | -293     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 37999    |
# |    policy_loss        | 1.16e-07 |
# |    value_loss         | 4.36e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 362       |
# |    iterations         | 38100     |
# |    time_elapsed       | 526       |
# |    total_timesteps    | 190500    |
# | train/                |           |
# |    entropy_loss       | -0.00187  |
# |    explained_variance | -2.76     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38099     |
# |    policy_loss        | -2.14e-07 |
# |    value_loss         | 1.47e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 362       |
# |    iterations         | 38200     |
# |    time_elapsed       | 527       |
# |    total_timesteps    | 191000    |
# | train/                |           |
# |    entropy_loss       | -0.0154   |
# |    explained_variance | -1.24e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38199     |
# |    policy_loss        | 3.91e-06  |
# |    value_loss         | 1.65e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 362       |
# |    iterations         | 38300     |
# |    time_elapsed       | 528       |
# |    total_timesteps    | 191500    |
# | train/                |           |
# |    entropy_loss       | -0.00138  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38299     |
# |    policy_loss        | -1.89e-09 |
# |    value_loss         | 2.2e-10   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 38400    |
# |    time_elapsed       | 529      |
# |    total_timesteps    | 192000   |
# | train/                |          |
# |    entropy_loss       | -0.00785 |
# |    explained_variance | -166     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38399    |
# |    policy_loss        | 9.09e-06 |
# |    value_loss         | 9.36e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 362       |
# |    iterations         | 38500     |
# |    time_elapsed       | 530       |
# |    total_timesteps    | 192500    |
# | train/                |           |
# |    entropy_loss       | -0.00183  |
# |    explained_variance | -82.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38499     |
# |    policy_loss        | -2.72e-08 |
# |    value_loss         | 2.85e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 362       |
# |    iterations         | 38600     |
# |    time_elapsed       | 531       |
# |    total_timesteps    | 193000    |
# | train/                |           |
# |    entropy_loss       | -0.00131  |
# |    explained_variance | -63.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38599     |
# |    policy_loss        | -1.59e-08 |
# |    value_loss         | 4.35e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 363       |
# |    iterations         | 38700     |
# |    time_elapsed       | 532       |
# |    total_timesteps    | 193500    |
# | train/                |           |
# |    entropy_loss       | -0.00278  |
# |    explained_variance | -1.47e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38699     |
# |    policy_loss        | 3.39e-07  |
# |    value_loss         | 1.04e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 363       |
# |    iterations         | 38800     |
# |    time_elapsed       | 534       |
# |    total_timesteps    | 194000    |
# | train/                |           |
# |    entropy_loss       | -0.00185  |
# |    explained_variance | -1.76e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38799     |
# |    policy_loss        | 2.82e-07  |
# |    value_loss         | 2.15e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 363       |
# |    iterations         | 38900     |
# |    time_elapsed       | 535       |
# |    total_timesteps    | 194500    |
# | train/                |           |
# |    entropy_loss       | -0.0146   |
# |    explained_variance | -14.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38899     |
# |    policy_loss        | -1.32e-05 |
# |    value_loss         | 5.21e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 39000    |
# |    time_elapsed       | 536      |
# |    total_timesteps    | 195000   |
# | train/                |          |
# |    entropy_loss       | -0.00229 |
# |    explained_variance | -378     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38999    |
# |    policy_loss        | 1.61e-09 |
# |    value_loss         | 3.24e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 363       |
# |    iterations         | 39100     |
# |    time_elapsed       | 538       |
# |    total_timesteps    | 195500    |
# | train/                |           |
# |    entropy_loss       | -0.00361  |
# |    explained_variance | -76.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39099     |
# |    policy_loss        | -2.22e-06 |
# |    value_loss         | 2.65e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 363       |
# |    iterations         | 39200     |
# |    time_elapsed       | 539       |
# |    total_timesteps    | 196000    |
# | train/                |           |
# |    entropy_loss       | -0.00199  |
# |    explained_variance | -348      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39199     |
# |    policy_loss        | -2.62e-08 |
# |    value_loss         | 1.85e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 39300    |
# |    time_elapsed       | 540      |
# |    total_timesteps    | 196500   |
# | train/                |          |
# |    entropy_loss       | -0.00152 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39299    |
# |    policy_loss        | 1.67e-08 |
# |    value_loss         | 1.41e-08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 39400    |
# |    time_elapsed       | 541      |
# |    total_timesteps    | 197000   |
# | train/                |          |
# |    entropy_loss       | -0.0046  |
# |    explained_variance | -16.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39399    |
# |    policy_loss        | 5.25e-07 |
# |    value_loss         | 4.61e-06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 363       |
# |    iterations         | 39500     |
# |    time_elapsed       | 543       |
# |    total_timesteps    | 197500    |
# | train/                |           |
# |    entropy_loss       | -0.00197  |
# |    explained_variance | -98.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39499     |
# |    policy_loss        | -3.76e-08 |
# |    value_loss         | 1.04e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 39600    |
# |    time_elapsed       | 544      |
# |    total_timesteps    | 198000   |
# | train/                |          |
# |    entropy_loss       | -0.00477 |
# |    explained_variance | -14.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39599    |
# |    policy_loss        | 3.26e-06 |
# |    value_loss         | 4.2e-05  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 39700    |
# |    time_elapsed       | 545      |
# |    total_timesteps    | 198500   |
# | train/                |          |
# |    entropy_loss       | -0.0043  |
# |    explained_variance | -20.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39699    |
# |    policy_loss        | 8.59e-07 |
# |    value_loss         | 3.1e-06  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 364       |
# |    iterations         | 39800     |
# |    time_elapsed       | 546       |
# |    total_timesteps    | 199000    |
# | train/                |           |
# |    entropy_loss       | -0.00389  |
# |    explained_variance | -677      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39799     |
# |    policy_loss        | -6.59e-07 |
# |    value_loss         | 5.3e-06   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 364       |
# |    iterations         | 39900     |
# |    time_elapsed       | 547       |
# |    total_timesteps    | 199500    |
# | train/                |           |
# |    entropy_loss       | -0.011    |
# |    explained_variance | -2.93e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39899     |
# |    policy_loss        | 6.32e-06  |
# |    value_loss         | 2e-05     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 364       |
# |    iterations         | 40000     |
# |    time_elapsed       | 548       |
# |    total_timesteps    | 200000    |
# | train/                |           |
# |    entropy_loss       | -0.00556  |
# |    explained_variance | -135      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39999     |
# |    policy_loss        | -1.84e-07 |
# |    value_loss         | 1.11e-06  |
# -------------------------------------

# %% [markdown]
# # Testing the Model

# %%
#Create a new environment with validation data
env = MyCustomEnv(df=data, window_size=window_size, frame_bound=(end_train_index, end_val_index))
obs = env.reset()

# %%
while True:
    obs = obs[np.newaxis, ...]
    action, _states = actor_critic.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        print("info", info)
        break
# Out:
# info {'total_reward': 22.93620000000007, 'total_profit': 0.4671671037320184, 'position': 1}

# %%
#Plot the results
plt.figure(figsize=(16,9))
env.render_all()
plt.show()

# %%
qs.extend_pandas()

net_worth = pd.Series(env.history['total_profit'], index=data.index[end_train_index+1:end_val_index])
returns = net_worth.pct_change().iloc[1:]

qs.reports.full(returns)

# %% [markdown]
# # Consider Joining the Newsletter
# Get updates on new vidoes, code, and discounts on future products / services
#
# https://witty-motivator-1414.ck.page/acb393f729
