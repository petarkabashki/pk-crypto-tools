// %%
println!("Hello wa")
// Out:
// Hello wa
// ()

// %%
add cbqn;
// Out:
// Error: expected `;`, found `cbqn`
//    ╭─[command_5:1:1]
//    │
//  1 │ add cbqn;
//    │    │──┬─
//    │    ╰────── error: expected `;`, found `cbqn`
//    │    │  │
//    │    ╰────── help: add `;` here: `;`
//    │       │
//    │       ╰─── unexpected token
// ───╯
// [E0425] Error: cannot find value `cbqn` in this scope
//    ╭─[command_5:1:1]
//    │
//  1 │ add cbqn;
//    │     ──┬─
//    │       ╰─── not found in this scope
// ───╯
